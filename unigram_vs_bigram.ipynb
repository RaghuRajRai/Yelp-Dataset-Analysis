# %% [markdown]
# # Unigrams v/s Bigrams v/s "UniBigrams?"

# %%
import pandas as pd

# %%
data1 = pd.read_table("E:\\Yelp\\Unfiltered Data\\YelpZip\\reviewContent", header=None)
data2 = pd.read_table("E:\\Yelp\\Unfiltered Data\\YelpZip\\metadata", header=None)

data2.head()

# %%
data = pd.merge(data1, data2, left_on=[0,2], right_on=[0,4], how='inner')

# %%
data.head()
data.drop(2, inplace=True, axis=1)
data.drop('1_x', inplace=True, axis=1)
data.drop(4, inplace=True, axis=1)
data.head()

# %%
data.head()
data.columns = ['id', 'date', 'text', 'item', 'rating', 'real']
data.head()

# %%
data.to_csv("E:\\Yelp\\Unfiltered Data\\YelpZip\\Customs\\MAIN", header=None)

# %%
data = data[(data['rating'] == 1) | (data['rating'] == 5)]

# %%
real_1 = data[(data['rating'] == 1) & (data['real'] == 1)] 
real_5 = data[(data['rating'] == 5) & (data['real'] == 1)] 
fake_1 = data[(data['rating'] == 1) & (data['real'] == -1)] 
fake_5 = data[(data['rating'] == 5) & (data['real'] == -1)] 

real = real_1.append(real_5, ignore_index=True)
real.shape
fake = fake_1.append(fake_5, ignore_index=True)
fake.shape

# %%
data = real.iloc[:10000,:].append(fake.iloc[:10000,:], ignore_index = True)

# %%
data.shape
# Out:
# (20000, 7)

# %%
data = pd.read_csv("E:\\Yelp\\Unfiltered Data\\YelpZip\\Customs\\SAMPLE", header=None)

# %%
from nltk.util import bigrams
import nltk

# %%
text = "Sample text. Just for fun!"
bigm = list(nltk.bigrams(text.split()))

# %%
bigm
# Out:
# [('Sample', 'text.'), ('text.', 'Just'), ('Just', 'for'), ('for', 'fun!')]

# %%
from nltk.corpus import stopwords
import string
stop_words=set(stopwords.words("english"))
print("Stopwords from the NLTK corpus: ", stop_words)

def text_process(text):
    #String punctuation provides all the necessary checks
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

import tqdm
tqdm.tqdm.pandas()
data[3] = data[3].progress_apply(lambda txt: text_process(txt))
# Out:
# Stopwords from the NLTK corpus:  {'doesn', 'before', "don't", 'because', 'against', 'about', 'below', "aren't", 'if', 'each', 'we', 'aren', 'the', 'for', 'be', 'yourselves', 'our', 'into', 'from', 'can', "hadn't", 'isn', 'with', "wouldn't", 'more', "should've", 'to', 'he', 'in', 'of', 'itself', 'd', 'theirs', 'too', 'she', 'all', "couldn't", 'not', 'y', 'a', 'myself', 'at', 'won', 'shouldn', 've', 'further', 'i', 'you', 'off', 'both', 'no', "shan't", 'its', 'there', 'are', 'why', 'wasn', 'mightn', 'will', 'during', 'and', 'them', "weren't", 'by', 'themselves', 'doing', 'after', 'they', 'having', "that'll", 'very', 'my', 'while', 'yourself', 's', "isn't", 'only', 'me', 'their', "hasn't", 'am', 'mustn', 'between', 'ours', 'when', 'couldn', 't', 'this', 'm', 'her', 're', "you've", 'was', 'up', 'didn', 'again', 'needn', 'which', 'his', 'through', 'that', 'were', 'don', 'above', 'than', 'now', 'until', 'being', "she's", 'does', 'own', 'once', 'him', 'your', "you'd", 'most', 'then', 'just'
# ...

# %%
def join_back(txt):
    new = ''
    for x in txt:
        new += ''.join(x)+" "
    new = new[:-1]
    return new

data[3] = data[3].progress_apply(lambda tokens: join_back(tokens))
# Out:
#   0%|                                                                                        | 0/20000 [00:00<?, ?it/s]
#
#
#  13%|█████████▍                                                                | 2550/20000 [00:00<00:00, 25445.79it/s]
#
#
#  29%|█████████████████████▏                                                    | 5713/20000 [00:00<00:00, 27001.43it/s]
#
#
#  43%|███████████████████████████████▉                                          | 8632/20000 [00:00<00:00, 27619.07it/s]
#
#
#  57%|█████████████████████████████████████████▎                               | 11321/20000 [00:00<00:00, 27393.09it/s]
#
#
#  73%|█████████████████████████████████████████████████████▎                   | 14603/20000 [00:00<00:00, 28816.46it/s]
#
#
#  87%|███████████████████████████████████████████████████████████████▌         | 17430/20000 [00:00<00:00, 28644.28it/s]
#
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data[3], data[6], test_size=0.25, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_test_counts = count_vect.fit_transform(X_test)
print(X_train_counts.shape)

#TFIDF is an important feature as it prevents the longer documents to be more biased. 
from sklearn.feature_extraction.text import TfidfTransformer
tf_trans = TfidfTransformer()
X_train_tf = tf_trans.fit_transform(X_train_counts)
X_test_tf = tf_trans.fit_transform(X_test_counts)
print(X_train_tf.shape)
# Out:
# (15000, 37330)
# (15000, 37330)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tf, y_train)

# %%
#Defining a pipeline for quick operations in the later stages

from sklearn.pipeline import Pipeline
text_clf = Pipeline([('vect', CountVectorizer()),('tfidf', TfidfTransformer()),('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=5, random_state=42))])

# %%
x = text_clf.fit(X_test, y_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
predicted = text_clf.predict(X_test)
print("Accuracy= ",np.mean(predicted == y_test)*100,"%")
# Out:
# Accuracy=  74.78 %

# %% [markdown]
# # Bigram performance:

# %% [markdown]
# ## with ngram_range = (2,2)
# ### Meaning "I love Data" -> [("I","love"), ("love","Data")]

# %%
test_vect = CountVectorizer(ngram_range=(2,2))
txt = "Sample text to check how the count vec with ngram range works"
test = test_vect.fit_transform([txt])
test_vect.get_feature_names()

#We can observe that the bigrams are working well
# Out:
# ['check how',
#  'count vec',
#  'how the',
#  'ngram range',
#  'range works',
#  'sample text',
#  'text to',
#  'the count',
#  'to check',
#  'vec with',
#  'with ngram']

# %%
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(2,2))),('tfidf', TfidfTransformer()),('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=5, random_state=42))])

# %%
x = text_clf.fit(X_test, y_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
predicted = text_clf.predict(X_test)
print("Accuracy= ",np.mean(predicted == y_test)*100,"%")
# Out:
# Accuracy=  50.56 %

# %% [markdown]
# ## with ngram_range = (1,2)
# ### Meaning "I love Data" -> [("I"), ("I","love"), ("love"),  ("love","Data"), ("Data")]

# %%
test_vect = CountVectorizer(ngram_range=(2,2))
txt = "Sample text to check how the count vec with ngram range works"
test = test_vect.fit_transform([txt])
test_vect.get_feature_names()

text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,2))),('tfidf', TfidfTransformer()),('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=5, random_state=42))])

x = text_clf.fit(X_test, y_test)

predicted = text_clf.predict(X_test)
print("Accuracy= ",np.mean(predicted == y_test)*100,"%")
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Accuracy=  76.84 %

# %% [markdown]
# # Conclusions
# ## Unigrams -> 74.78 %
# ## Bigrams ->  50.56 %
# ## Unigrams+Bigrams -> 76.84 %
#
# ## We can conclude that Unigrams+Bigrams seem to perform better in this Sample data.
#
# # NOTE: This was done on a sampled data of 20,000 tuples with an equal amount of real and fake reviews. Actual performance on the full sized dataset may differ.
